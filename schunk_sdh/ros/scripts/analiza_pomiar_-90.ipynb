# %%
import pickle

# %%
log=pickle.load(open("kat_A1m45","rb"))

# %%
import numpy
srednie_leap = numpy.array([list(numpy.mean(numpy.array(ll[0]),0)) for ll in log])
odchylenia_leap = numpy.array([list(numpy.std(numpy.array(ll[0]),0)) for ll in log])

print srednie_leap
print odchylenia_leap
# Out:
# [[  31.01998952  209.32540843 -107.10699209]
#  [  40.99195099  208.49401855  -97.37826538]
#  [  33.97063354  208.86983832 -103.59628085]
#  [  39.46287116  208.58655627  -98.43280292]
#  [  43.9487648   208.52749634  -94.73339081]
#  [  43.21458346  208.54547373  -95.54657262]
#  [  42.2163684   208.55669512  -96.26544762]
#  [  41.60803617  208.58997142  -96.86909968]
#  [  40.9642142   208.64470011  -97.4624733 ]
#  [  42.31500639  208.5672418   -96.06599111]
#  [  39.2354785   208.68220046  -99.12753296]
#  [  39.60121957  208.66472705  -98.81044796]
#  [  39.58863436  208.72163023  -98.86712278]
#  [  40.34523839  208.65595324  -98.07179602]
#  [  38.52898433  208.69884096  -99.72886132]
#  [  39.82370063  208.67749132  -98.56353869]
#  [  44.10602241  208.54719912  -94.68107368]
#  [  37.79118867  208.71871317 -100.40592062]
#  [  39.38118235  208.66031952  -98.98991241]
#  [  43.39090413  208.57038827  -95.34223307]
#  [  43.62211754  208.49777274  -95.01763811]
# ...

# %%
print len(log)
# Out:
# 70

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
fig = plt.figure(figsize=(15,6))
ax = fig.add_subplot(1,1,1, projection='3d')
plot(srednie_leap[:,2],srednie_leap[:,1],srednie_leap[:,0], 'b.')

# %%
czwa=numpy.array(log[69][0])

# %%
plot(numpy.linspace(0,20,czwa.shape[0]),czwa[:,2],'r*')
#xlabel("2 t[s]")
xlabel("time [s]")
ylabel("leap motion reading,x axis [mm]")
title("Leap Motion reading stabilisation")
