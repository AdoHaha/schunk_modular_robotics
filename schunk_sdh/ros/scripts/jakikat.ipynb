# %%
'''prediction node'''
import roslib; 
roslib.load_manifest('schunk_sdh')
import sys 
import rospy
import roslib
import cob_srvs.srv
import std_msgs.msg
import control_msgs.msg
import actionlib_msgs.msg
import trajectory_msgs.msg
import collections
from std_msgs.msg import String
from std_msgs.msg import Float64
from dlonurdf.msg import Rekawica
from dlonurdf.msg import Hand
from handkinect.msg import JakieKaty
import numpy as np
from sklearn.svm import SVC
import sklearn
import pylab
from sklearn import cross_validation
import pickle
import std_msgs.msg
from std_msgs.msg import Float32

# %%
rospy.init_node('jakikat')

# %%
katy=JakieKaty()
def podajkat(rekawica):
    global katy
    ###testowy nod podajacy index finger
    zrekawicy=rekawica
    zrek=rekawica
    xvector=np.array([[zrekawicy.kciuk0,zrekawicy.palwska0,zrekawicy.palsro0,
             zrekawicy.palser0,zrekawicy.palmal0,zrekawicy.palmal1,
             zrekawicy.palser1,zrekawicy.palsro1,
             zrekawicy.palwska1,zrekawicy.kciuk1]])
    print xvector.shape
    x=vstack((xvector,np.ones(xvector.shape)))
    A=np.array([[-0.00085548,-0.19016596],[0.00611806,-1.58558978],[0.0050781,-1.57497518],[0.00509308,-1.85961611],
                [0.00664456,-1.72292413],[ 0.00677017,-2.3479249],
                [0.00971227,-3.2004507],[0.0050781,-1.57497518],
                [0.0107216,-4.03050489],[-0.00821128,2.00232814]
                
                ])
    print x.shape, A.shape
    #res=np.dot(A,x.T)
    res= np.sum(A*x.T,1)    
    katy.thumb_p=res[0]
    katy.index_p=res[1]
    katy.middle_p=res[2]
    katy.ring_p=res[3]
    katy.pinky_p=res[4]
    katy.pinky_d=res[5]
    katy.ring_d=res[6]
    katy.middle_d=res[7]
    katy.index_d=res[8]
    katy.thumb_d=res[0]
    
    #print res
                
    #obliczenia=(-1.63679866+0.00612564*zrek)*360/(2*math.pi)
    #obliczenia=(0.0107216*zrek-4.03050489)*360/(2*math.pi)
    #print "wchodze"
    pub.publish(katy)

# %%
pub = rospy.Publisher('/jakikat', JakieKaty)
rospy.Subscriber("rekawica",Rekawica,podajkat)

# %%
A=np.array([[-0.00821128,2.00232814],[0.00612564,-1.63679866],[0.0050781,-1.57497518],[0.00509308,-1.85961611],
                [0.00664456,-1.72292413],[ 0.00677017,-2.3479249],
                [0.00971227,-3.2004507],[0.0050781,-1.57497518],
                [0.0107216,-4.03050489],[-0.00821128,2.00232814]
                
                
                
                
                ])
# Out:
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# ...

# %%
print "fufu"
# Out:
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# (2, 10) (10, 2)
# (1, 10)
# ...

# %%
import pip
from subprocess import call

for dist in pip.get_installed_distributions():
    call("pip install --upgrade " + dist.project_name, shell=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f5f8ed6bdb7f> in <module>()
#       3
#       4 for dist in pip.get_installed_distributions():
# ----> 5     call("pip install --upgrade " + dist.project_name, shell=True)
#
# /usr/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     491     retcode = call(["ls", "-l"])
#     492     """
# --> 493     return Popen(*popenargs, **kwargs).wait()
#     494
#     495
#
# /usr/lib/python2.7/subprocess.pyc in wait(self)
#    1289             if self.returncode is None:
#    1290                 try:
# -> 1291                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1292                 except OSError as e:
#    1293                     if e.errno != errno.ECHILD:
#
# /usr/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     476     while True:
#     477         try:
# ...
