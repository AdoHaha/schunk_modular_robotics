# %%
#sudo rfcomm connect 1import serialimport timeimport structimport termiosser = serial.Serial('/dev/ttyACM0',9600,timeout=1)ser.open()fileczyth=open("filehotzg3dluga.txt","w")#ser.read(1000000000)for nn in range(0,5*4*3600):# five hours        arraydoczytania=[]    while(ser.inWaiting()>0):        arraydoczytania.append(ser.readline())    if(nn%40==0):            print nn/4, arraydoczytania[-1]    #print nn/4, arraydoczytania[-1]    fileczyth.writelines(arraydoczytania)    time.sleep(0.25)fileczyth.close()ser.close()#ser = serial.Serial('/dev/rfcomm0',57600,timeout=0.02)#ser.flushInput()
# Out:
# 0 309 318 311 335 288 221 0 0 243 220 275 280 0 74 0 0 29.00 55701110
#  310 318 311 335 288 222 0 0 243 221 276 280 0 64 0 0 29.06 56902420
#  310 319 311 335 289 222 0 0 243 221 276 280 0 56 0 0 29.19 58137930
#  310 318 311 335 289 222 0 0 243 222 276 280 0 52 0 0 29.25 59373440
#  311 318 311 335 289 222 0 0 243 222 276 280 0 45 0 0 29.31 60636450
#  311 318 311 335 290 223 0 0 243 222 276 280 0 9 0 0 29.44 61871560
#  311 319 310 335 291 223 0 0 244 222 277 281 0 8 0 0 29.56 63698070
#  311 319 311 335 291 224 0 0 244 222 277 281 0 0 0 0 29.75 65590780
#  311 318 311 336 291 223 0 0 244 223 276 281 0 0 0 0 29.87 67429490
#  311 318 311 335 292 224 0 0 245 223 277 281 0 0 0 0 30.06 694102100
#  311 319 311 335 292 224 0 0 245 223 277 281 0 0 0 0 30.25 712353110
#  311 319 311 335 292 225 0 0 245 224 277 282 0 0 0 0 30.44 730605120
#  312 319 311 336 293 225 0 0 245 224 277 281 0 0 0 0 30.62 750547130
#  312 319 310 336 293 225 0 0 245 224 277 282 0 0 0 0 30.81 769475140
# ...

# %%
a=[1,2,3]print a[-1]
# Out:
# 3
